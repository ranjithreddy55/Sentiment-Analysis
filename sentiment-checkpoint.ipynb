# %%
import os
print(os.getcwd())
# Out:
# C:\Sentiment-Analysis

# %%
import os
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'data', 'images', 'models', 'notebooks', 'requirements.txt', 'src', 'test.csv', 'Untitled.ipynb', 'Untitled1.ipynb', 'Untitled2.ipynb', 'venv']

# %%
print(os.listdir("data"))
# Out:
# ['test.csv']

# %%
import pandas as pd

df = pd.read_csv("test.csv")

# %%
print(df.head())
print(df.columns)
print(df.shape)
# Out:
#                                                 text sentiment
# 0  My daughter liked it but I was aghast, that a ...       neg
# 1  I... No words. No words can describe this. I w...       neg
# 2  this film is basically a poor take on the old ...       neg
# 3  This is a terrible movie, and I'm not even sur...       neg
# 4  First of all this movie is a piece of reality ...       pos
# Index(['text', 'sentiment'], dtype='object')
# (25000, 2)

# %%
print(df.columns)
print(df.head())
# Out:
# Index(['text', 'sentiment'], dtype='object')
#                                                 text sentiment
# 0  My daughter liked it but I was aghast, that a ...       neg
# 1  I... No words. No words can describe this. I w...       neg
# 2  this film is basically a poor take on the old ...       neg
# 3  This is a terrible movie, and I'm not even sur...       neg
# 4  First of all this movie is a piece of reality ...       pos

# %%
df.shape
# Out:
# (25000, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   text       25000 non-null  object
#  1   sentiment  25000 non-null  object
# dtypes: object(2)
# memory usage: 390.8+ KB

# %%
df.isnull().sum()
# Out:
# text         0
# sentiment    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(199)

# %%
df["sentiment"].value_counts()
# Out:
# sentiment
# neg    12500
# pos    12500
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6,4))
sns.countplot(x="sentiment", data=df)
plt.title("Sentiment Distribution")
plt.xlabel("Sentiment")
plt.ylabel("Count")
plt.show()

# %%
df["review_length"] = df["text"].apply(len)

# %%
df[["text", "review_length"]].head()
# Out:
#                                                 text  review_length
# 0  My daughter liked it but I was aghast, that a ...            811
# 1  I... No words. No words can describe this. I w...           1814
# 2  this film is basically a poor take on the old ...            701
# 3  This is a terrible movie, and I'm not even sur...            866
# 4  First of all this movie is a piece of reality ...            978

# %%
df["review_length"].describe()
# Out:
# count    25000.00000
# mean      1293.79240
# std        975.90776
# min         32.00000
# 25%        696.00000
# 50%        962.00000
# 75%       1572.00000
# max      12988.00000
# Name: review_length, dtype: float64

# %%
plt.figure(figsize=(10,5))
plt.hist(df["review_length"], bins=50)
plt.title("Distribution of Review Length")
plt.xlabel("Number of Characters")
plt.ylabel("Frequency")
plt.show()

# %%
pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in .\venv\lib\site-packages (1.9.6)
# Requirement already satisfied: numpy>=1.19.3 in .\venv\lib\site-packages (from wordcloud) (2.2.6)
# Requirement already satisfied: pillow in .\venv\lib\site-packages (from wordcloud) (12.3.0)
# Requirement already satisfied: matplotlib in .\venv\lib\site-packages (from wordcloud) (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in .\venv\lib\site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in .\venv\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in .\venv\lib\site-packages (from matplotlib->wordcloud) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\venv\lib\site-packages (from matplotlib->wordcloud) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in .\venv\lib\site-packages (from matplotlib->wordcloud) (26.2)
# Requirement already satisfied: pyparsing>=3 in .\venv\lib\site-packages (from matplotlib->wordcloud) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in .\venv\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in .\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

positive_text = " ".join(df[df["sentiment"] == "pos"]["text"])

wordcloud = WordCloud(
    width=800,
    height=400,
    background_color="white"
).generate(positive_text)

plt.figure(figsize=(12,6))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title("Positive Reviews Word Cloud")
plt.show()
